# %% [markdown]
# # **Variables:-**

# %%
a=10
b=20
print(a,b)
# Out:
# 10 20

# %% [markdown]
# #***Quotes:-***

# %%
print("Hi, My name is Aahil")
# Out:
# Hi, My name is Aahil

# %% [markdown]
# #***Lists:-***

# %%
Games=["Valorant","DMC","Resident Evil","Halo"]
print(Games)
print(type(Games))
# Out:
# ['Valorant', 'DMC', 'Resident Evil', 'Halo']
# <class 'list'>

# %% [markdown]
# #***Tuples:-***

# %%
name=("Aahil","Jivin","Sanjeev")
Name=list(name)
Name[2]="Bharat"
print(Name)
Roll_Numbers=(2,22,13)
print(Name,Roll_Numbers)
# Out:
# ['Aahil', 'Jivin', 'Bharat']
# ['Aahil', 'Jivin', 'Bharat'] (2, 22, 13)

# %% [markdown]
# #***Mathematic Operations:-***

# %%
x=50
y=20
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
# Out:
# 70
# 30
# 1000
# 2.5
# 10

# %% [markdown]
# # **Arrays:-**

# %%
colour=['white',"red"]
print(colour)
colour.insert(1,"blue")
colour.remove("white")
print(colour)
colour.append("yellow")
colour
# Out:
# ['white', 'red']
# ['blue', 'red']
# ['blue', 'red', 'yellow']

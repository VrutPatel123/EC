# %% [markdown]
# #***Adding Digits of 5 Digit Number***

# %%
def sum_digits(n):
  if n < 10 and n >= 0:
    return n
  elif n < 0:
    n = -n
    return n % 10 + sum_digits(n // 10)
  else:
    return n % 10 + sum_digits(n // 10)
x = input('Enter a 5-Digit Number: ')
x = int(x)
print(sum_digits(x))
# Out:
# Enter a 5-Digit Number: -53251
# 16
